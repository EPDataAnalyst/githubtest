# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/Salaries.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0           1      Prof          B             19           18  Male  139750
# 1           2      Prof          B             20           16  Male  173200
# 2           3  AsstProf          B              4            3  Male   79750
# 3           4      Prof          B             45           39  Male  115000
# 4           5      Prof          B             40           41  Male  141500

# %%
df.shape  #Shape=total number of rows and columns
# Out:
# (397, 6)

# %%
df.isnull().value_counts() #No Missing values
# Out:
# rank   discipline  yrs.since.phd  yrs.service  sex    salary
# False  False       False          False        False  False     397
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'rank', 'discipline', 'yrs.since.phd', 'yrs.service',
#        'sex', 'salary'],
#       dtype='object')

# %%
df.mean() #salary           $113706.46
# Out:
# <ipython-input-5-d50e34cfe628>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean() #salary           $113706.46
# Unnamed: 0          199.000000
# yrs.since.phd        22.314861
# yrs.service          17.614610
# salary           113706.458438
# dtype: float64

# %%
df['salary'].median() #median salary 107300
# Out:
# 107300.0

# %%
df.groupby(df['rank'])['salary'].median().sort_values().plot(kind='bar',rot=0)
#df_grouped = df.groupby(df['rank'])['salary'].median().plot(kind='bar',rot=0)
#df_sorted = dfgrouped.sort_values()
plt.show()

# %%
df.groupby(df['sex'])['salary'].median().plot(kind='pie')
# Out:
# <Axes: ylabel='salary'>

# %%
df.groupby(df['sex']).count()
# Out:
#         rank  discipline  yrs.since.phd  yrs.service  salary
# sex
# Female    39          39             39           39      39
# Male     358         358            358          358     358

# %%
39/397 #less thank 10% of the staff are women.
# Out:
# 0.0982367758186398

# %%
df.describe()
# Out:
#        Unnamed: 0  yrs.since.phd  yrs.service         salary
# count  397.000000     397.000000   397.000000     397.000000
# mean   199.000000      22.314861    17.614610  113706.458438
# std    114.748275      12.887003    13.006024   30289.038695
# min      1.000000       1.000000     0.000000   57800.000000
# 25%    100.000000      12.000000     7.000000   91000.000000
# 50%    199.000000      21.000000    16.000000  107300.000000
# 75%    298.000000      32.000000    27.000000  134185.000000
# max    397.000000      56.000000    60.000000  231545.000000

# %%
df.set_index('Unnamed: 0', inplace = True)
df.index.name = 'index'
df.reset_index(inplace=True)

# %%
df.columns
# Out:
# Index(['index', 'rank', 'discipline', 'yrs.since.phd', 'yrs.service', 'sex',
#        'salary'],
#       dtype='object')

# %%
df.head()
# Out:
#    index      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0      1      Prof          B             19           18  Male  139750
# 1      2      Prof          B             20           16  Male  173200
# 2      3  AsstProf          B              4            3  Male   79750
# 3      4      Prof          B             45           39  Male  115000
# 4      5      Prof          B             40           41  Male  141500

# %%
df.set_index('index', inplace=True)

# %%
df.head()
# Out:
#            rank discipline  yrs.since.phd  yrs.service   sex  salary
# index
# 1          Prof          B             19           18  Male  139750
# 2          Prof          B             20           16  Male  173200
# 3      AsstProf          B              4            3  Male   79750
# 4          Prof          B             45           39  Male  115000
# 5          Prof          B             40           41  Male  141500

# %%
df.groupby(df['rank'])['salary'].median().plot(kind='bar',rot=0)(df['rank'])['salary'][salary].mean().plot(kind='bar',rot=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8031f047cfb7> in <cell line: 1>()
# ----> 1 df.groupby(df['rank'])['salary'][salary].mean().plot(kind='bar',rot=0)
#
# NameError: name 'df' is not defined
